# %%
name('Hello World')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b49118aa999f> in <module>()
# ----> 1 name('Hello World')
#
# NameError: name 'name' is not defined

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("eymen ders Hello World!")
# Out:
# eymen ders Hello World!

# %%
print("oğlum dersini aç tenefüse daha var!")
# Out:
# oğlum dersini aç tenefüse daha var!

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e965a2e3f2d1> in <module>()
# ----> 1 Print('hello')
#
# NameError: name 'Print' is not defined

# %%
print("ders ders ders")
# Out:
# ders ders ders

# %%
print( "I'm happy to learn")
# Out:
# I'm happy to learn

# %%
print('ajshfja "22222233333333" ')
# Out:
# ajshfja "22222233333333"

# %%
print("hfjdsfdf6")
# Out:
# hfjdsfdf6

# %%
print'''dsfdgfdg
fgfdgsd
gsdfgfdg
23335'''
# Out:
#   File "<ipython-input-19-64ee81073be3>", line 4
#     23335'''
#
# ^
# SyntaxError: invalid syntax

# %%
print('''hgshgsd gsdıusdug
djhgksdhgkjsd

222222222''')
# Out:
# hgshgsd gsdıusdug
# djhgksdhgkjsd
#
# 222222222

# %% [markdown]
# notlarım

# %%
print("""bana topçu diye bağırdı.dersine bakkkkkkkkkkkkk """)
# Out:
# bana topçu diye bağırdı.dersine bakkkkkkkkkkkkk

# %%
print('''ders''')
# Out:
# ders

# %% [markdown]
# ders çalışşşş

# %%
print('''bana güzelce seslendi''')
# Out:
# bana güzelce seslendi

# %%
print('''fdsmbf jdsfndj     jdnfjdsng   
jfdjgndjskgn  ndjgnfjd harabjaber''')
# Out:
# fdsmbf jdsfndj     jdnfjdsng
# jfdjgndjskgn  ndjgnfjd harabjaber

# %%
print('3.14')
print(3.14)
# Out:
# 3.14
# 3.14

# %%
print("print(3.14)")
# Out:
# print(3.14)

# %%
print(''''dkjshgkjs djg jds dj''')
# Out:
# 'dkjshgkjs djg jds dj

# %%
print("""dfgfdgfdhdfhfd'""")
# Out:
# dfgfdgfdhdfhfd'

# %%
print(''''''''''')
# Out:
#   File "<ipython-input-32-ca57ebfb912c>", line 1
#     print(''''''''''')
#                       ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print('''''''''''')

# %%
print("""1""""""1""")
# Out:
# 11

# %%
print("""222"""'''222222222''')
# Out:
# 222222222222

# %%
print('''')
# Out:
#   File "<ipython-input-39-4b777b03c816>", line 1
#     print('''')
#                ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print(''')
# Out:
#   File "<ipython-input-41-c6d045ece466>", line 1
#     print(''')
#               ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
print("python enhancement proposal")
# Out:
# python enhancement proposal
